# %%
import pandas as pd

#performance_path = './performance.xlsx'
performance = pd.read_excel('C:/Users/user/Downloads/01_제공데이터/2020 빅콘테스트 데이터분석분야-챔피언리그_2019년 실적데이터.xlsx')
performance.columns=['방송일시', '노출(분)', '마더코드', '상품코드', '상품명', '상품군', '판매단가', '취급액']
performance = performance.drop([0])
performance
# Out:
#                       방송일시    노출(분)    마더코드    상품코드                       상품명  \
# 1      2019-01-01 06:00:00       20  100346  201072             테이트 남성 셀린니트3종
# 2      2019-01-01 06:00:00      NaN  100346  201079             테이트 여성 셀린니트3종
# 3      2019-01-01 06:20:00       20  100346  201072             테이트 남성 셀린니트3종
# 4      2019-01-01 06:20:00      NaN  100346  201079             테이트 여성 셀린니트3종
# 5      2019-01-01 06:40:00       20  100346  201072             테이트 남성 셀린니트3종
# ...                    ...      ...     ...     ...                       ...
# 38305  2020-01-01 00:20:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험(1912)
# 38306  2020-01-01 00:40:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험(1912)
# 38307  2020-01-01 01:00:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험(1912)
# 38308  2020-01-01 01:20:00       20  100490  201478        더케이 예다함 상조서비스(티포트)
# 38309  2020-01-01 01:40:00  17.1667  100490  201478        더케이 예다함 상조서비스(티포트)
#
#       상품군   판매단가      취급액
# ...

# %%
#무형은 추정에서 제외
idx1=performance[performance['상품군']=='무형'].index
performance=performance.drop(idx1)

# %%
performance[performance['상품군']=='무형'].count()
# Out:
# 방송일시     0
# 노출(분)    0
# 마더코드     0
# 상품코드     0
# 상품명      0
# 상품군      0
# 판매단가     0
# 취급액      0
# dtype: int64

# %%
mothercode = list(performance['마더코드'])
items = list(performance['상품명'])

company_names = ['테이트', '오모떼', '보코', 'CERINI by PAT', '크로커다일', '에코라믹', '그렉노먼', '비버리힐스폴로클럽', '푸마', 'LG', '마리노블', '헤스티지', '로베르타 디 까메리노', '레이프릴', '벨라홈', '종근당건강', '하늘내린', 'SPC삼립', '바다먹자', '키친플라워', '피시원', '청정수산', '삼성', '한일', '에버홈', '임페리얼', '루이띠에', '쿠첸', '보몽드', '보루네오', '프라다', '셰프웨이', '레코바', '한샘', '하림', '뉴트리원', '코몽트', '파뷔에', '스프리스', '가이거', '딤채', '쿠쿠', '일월', '삼익가구', '장수', '메디아글램', '블랙모어스', '한솔', '보국', '라니', 'USPA', '글라스락', '기라로쉬', '메리츠', 'K-SWISS', 'EXR', '본죽', '바다원', '살롱클리닉', '세라맥스', '수협', '슬로푸드', '안드레아바나', 'RYN', 'NNF', '남영비비안', '페플럼제이', '광동', '구찌', '경남제약', '구스터', '모나코사놀', '노송가구', '까사마루', '뉴욕맘', '중외신약', 'DIOR', '농협', '디즈니', '디키즈', '라쉬반', '레노마', '레드캠프', '레스토닉', '로벤탈', '르까프', '리복', '도스문도스', '도루코', '라라쎄', '란체티', '마르엘라로사티', '마리끌레르', '마모트', '마스케라', '마이클코어스', '메디앤서', '대동모피', '더블유베일', '도네이', '대우전자', '린나이', '락앤락', '아이넥스', '뱅뱅', '뷰티플렉스', '블루콤', '블링썸', '사운드룩', '노와', '아키', '아리스토우', '아문센', '아미니', '아이앤아이', '리앤', '메이듀', '몬테밀라노', '넥센타이어', '롯데', '쿠미투니카', '퀸메이드', '크리스티나앤코', '코치', '코펜하겐럭스', '크린조이', '키친아트', '트레스패스', '헤비추얼', '효재', '하나투어', '팜스프링스', '모즈', '버버리', '삭루츠', '생쥴랑', '생줄랑', '알비에로 마르티니', '에델코첸', '에르나벨', '에트로', '에버라스트', '에펨', '엘렌실라', '오가닉뷰티', '오델로', '오렐리안', '월드컵', '라라츄', '실크트리', '썸덱스', '아가타', '아르테사노', '알렉스하운드', '유캐슬', '이동수골프', '이조농방', '자미코코', '참좋은여행', '천연담아', '카파', '칼리베이직', '캐치온', '컬럼비아', '코튼데이', '코튼플러스', '타운젠트', '니봇', '한빛', '굿프렌드', '캐리어', '매직쉐프', '제옥스', '젠트웰', '코지마', '파로마', '페르소나', '쿠진', '에지리', '에코바이런', '바바코코', '베스트하임', '베스트 하임', '스칸디나비아', '스포메틱스', '스피드랙', '스튜디오럭스', '사르마르스', '온라인투어', '테팔', '브람스안마의자', '바디프랜드', '아이러너', '현대해상', '현대렌탈케어', '히트융', 'TS', '월시스', '참바다', '제주바다', '통영바다의보물', 'VONIN', '센스하우스', '투홀릭', '플로쥬', '소들녘', '시스마르스', '이누스바스', '올리고', '루시헨느', '루이바셋', '올바로', '목우촌', '선일금고', '마이베비', '메디쉴드', '메디컬드림', '휴롬', '베지밀', '히팅맘', ]

person_names = ['송도순', '유귀열', '팽현숙', '김병만', '김병지', '김선영', '김정문', '김정배', '이경제', '이만기', '이보은', '이봉원', '이정섭', '임성근', '강레오', '최인선', ]

item_names = ['헤드 ', '바로바로 무선청소기', '현대어찬 손질갈치', '궁중 손질새우', '손질 생선 3대세트', '갑오징어', '통오징어', '가자미', '병어', '새꼬막', '피꼬막', '왕꼬막', '붙이는 따스림 실크 단열벽지', '두꺼비 매직 버블수세미', '영광 生 모시떡', '영산포숙성 홍어', '구워만든 곡물그대로']

unknown_names = ['AAA', 'AAB', 'AAC', 'AAD', 'AAE', ]

name_list = company_names + person_names + item_names + unknown_names

print(len(set(mothercode)))
print(len(set(items)))
print(len(items))
companies = {}
remains = set()
for m, i in zip(mothercode, items):
    already_find = False
    for n in name_list:
        if n in i:
            if (n == '삼성' and ('삼성카드' in i or 'SKT' in i)) or \
               (n == '노와' and '노와이어' in i) or \
               (n == '캐리어' and '에어컨' not in i) or \
               (n == 'TS' and 'TS100' in i):
                continue
            already_find = True
            break

    if already_find:
        continue

    remains |= set([i])
print(len(remains))
for r in sorted(remains):
    print(r)
# Out:
# 687
# 1692
# 37372
# 215
#  국내제조 오슬로 IH 프라이팬 세트
#  서울대 더 리얼 신바이오틱스 6박스 (6개월분)
#  한국인 모유유래 다이어트 유산균 BNR17 비에날씬 12주(3박스)
# " 100%리얼 착즙 석류 ", 총 4박스
# (무)100%리얼착즙석류 4박스
# (일)100%리얼착즙석류 4박스
# 1세트 믹서를 품은 텀블러
# 1세트 센티멘탈 디퓨저골드
# 2019 S/S 엘리자베스아덴 선글라스 2종
# 2세트 믹서를 품은 텀블러
# 3D매쉬  냉수마찰  물매트
# 5세트 센티멘탈 디퓨저골드패키지
# AHC 스킨케어링 톤커버크림
# ALL New 파워스윙 물걸레 진공청소기
# BBC&IZUMI 레이스런닝 브라 패키지
# IH 옛 가마솥 세트
# KF94 엔웰스황사방역마스크 100매
# LSX라이크라 스포츠 브라팬티10종
# OK 근육통완화 동전패치
# SK매직 파워워시 식기세척기 터치온
# [가격인하]전철우 소갈비살구이 10팩
# [실속패키지]레스트업 수액패치(50매)
# [유리진] 19Fall 코튼블렌딩 실켓티블라우스5종
# [특등급] 김천 샤인머스켓 2kg (2~3수)
# [풀패키지]레스트업 수액패치(84매)
# am마카롱 보온병세트
# 가)세렌셉템버 다이아 체크 리빙박스+압축팩
# 갈란테 프리미엄 에디션(남성화 3종 + 면도기 1종)
# 강원도양구 간편시래기 + 시래기 들깨 무침
# 강원도양구 간편시래기15팩
# 거미손 차량용 공기청정기
# 거창특등급사과 5kg+5kg
# 고데롤 플러스
# 고창 꿀 고구마 10kg
# 고칼슘검은콩두유48팩+호두아몬드 두유48팩
# 골드파일 카로 여행가방 9종 세트
# 국내산 신안생물 생새우 1.2kg
# 국내산 자숙찰골뱅이 7팩
# 국내산참조기12팩
# 국내생산 스텐락 심플 스텐밀폐용기 17종
# 궁중 해물철판 10팩
# 기본구성 바로톡 싱크대 거름통
# 네오젠 에이지큐어 원미닛 링클 리프트
# 네페르티티 유기농 퀸 석류즙 6박스
# 노비타 스마트 비데
# ...

# %%
'''
items
#대부분 브랜드가 맨 앞에 나오니까 0번째 인덱스만 추출
com_names=list()
for i in range(len(items)):
    temp=items[i].split()
    com_names.append(temp[0])
print(com_names)
'''
# Out:
# '\nitems\n#대부분 브랜드가 맨 앞에 나오니까 0번째 인덱스만 추출\ncom_names=list()\nfor i in range(len(items)):\n    temp=items[i].split()\n    com_names.append(temp[0])\nprint(com_names)\n'

# %%
#가이거 시계 브랜드
def is_not_com(List):
    for i in range(len(List)):
        if (List[i]=='(렌탈)') or(List[i]=='일시불') or (List[i]=='무이자') or (List[i]=='(렌탈)'):
            del List[i]
        elif (List[i]=='직매입')or (List[i]=='(도냄)일시불') or (List[i]=='(도냄)무이자') or (List[i]=='2세트'):
            del List[i]
        elif (List[i]=='(직매입)') or (List[i]=='국내산') or(List[i]=='국내제작') or (List[i]=='1세트'):
            del List[i]
        elif (List[i]=='(일시불)') or (List[i]=='국내제조') or (List[i]=='초특가'):
            del List[i]
        return List

# %%
'''
com_names=is_not_com(com_names)
new_list = []
for v in com_names:
    if v not in new_list:
        new_list.append(v)
print(new_list)
'''
# Out:
# '\ncom_names=is_not_com(com_names)\nnew_list = []\nfor v in com_names:\n    if v not in new_list:\n        new_list.append(v)\nprint(new_list)\n'

# %%
#성별 분류
#남자
male=performance[performance['상품명'].str.contains('남성' or'남자')]
male
# Out:
#                       방송일시 노출(분)    마더코드    상품코드  \
# 1      2019-01-01 06:00:00    20  100346  201072
# 3      2019-01-01 06:20:00    20  100346  201072
# 5      2019-01-01 06:40:00    20  100346  201072
# 10     2019-01-01 08:00:00    20  100808  202377
# 11     2019-01-01 08:20:00    20  100808  202377
# ...                    ...   ...     ...     ...
# 38185  2019-12-30 20:40:00    20  100074  200199
# 38186  2019-12-30 21:00:00    20  100074  200199
# 38217  2019-12-31 08:20:00    20  100390  201261
# 38219  2019-12-31 08:40:00    20  100390  201261
# 38221  2019-12-31 09:00:00    20  100390  201261
#
#                                  상품명  상품군   판매단가       취급액
# 1                      테이트 남성 셀린니트3종   의류  39900   2099000
# 3                      테이트 남성 셀린니트3종   의류  39900   3262000
# 5                      테이트 남성 셀린니트3종   의류  39900   6672000
# 10     CERINI by PAT 남성 소프트 기모 릴렉스팬츠   의류  59900  16133000
# 11     CERINI by PAT 남성 소프트 기모 릴렉스팬츠   의류  59900  30061000
# ...

# %%
#여자
fem=performance[performance['상품명'].str.contains('여성' or'여자')]
fem
# Out:
#                       방송일시 노출(분)    마더코드    상품코드  \
# 2      2019-01-01 06:00:00   NaN  100346  201079
# 4      2019-01-01 06:20:00   NaN  100346  201079
# 6      2019-01-01 06:40:00   NaN  100346  201079
# 27     2019-01-01 14:00:00   NaN  100377  201226
# 29     2019-01-01 14:30:00   NaN  100377  201226
# ...                    ...   ...     ...     ...
# 38063  2019-12-29 08:40:00   NaN  100390  201264
# 38065  2019-12-29 09:00:00   NaN  100390  201264
# 38218  2019-12-31 08:20:00   NaN  100390  201264
# 38220  2019-12-31 08:40:00   NaN  100390  201264
# 38222  2019-12-31 09:00:00   NaN  100390  201264
#
#                                  상품명 상품군    판매단가       취급액
# 2                      테이트 여성 셀린니트3종  의류   39900   4371000
# 4                      테이트 여성 셀린니트3종  의류   39900   6955000
# 6                      테이트 여성 셀린니트3종  의류   39900   9337000
# 27               그렉노먼 여성 구스다운 롱 벤치코트  의류  119000  20841000
# 29               그렉노먼 여성 구스다운 롱 벤치코트  의류  119000  47294000
# ...

# %%
#결제방식

무이자=performance[performance['상품명'].str.contains('무이자' or'(무이자)')]
무이자
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                       상품명  \
# 46     2019-01-01 20:00:00   NaN  100150  200465            무이자 LG 통돌이 세탁기
# 48     2019-01-01 20:20:00   NaN  100150  200465            무이자 LG 통돌이 세탁기
# 50     2019-01-01 20:40:00   NaN  100150  200465            무이자 LG 통돌이 세탁기
# 81     2019-01-02 10:00:00   NaN  100448  202093  무이자 쿠첸 풀스텐 압력밥솥 10인용(A1)
# 83     2019-01-02 10:00:00   NaN  100448  202095   무이자 쿠첸 풀스텐 압력밥솥 6인용(A1)
# ...                    ...   ...     ...     ...                       ...
# 38295  2019-12-31 23:20:00   NaN  100448  201384             무이자쿠첸압력밥솥 6인용
# 38297  2019-12-31 23:40:00    20  100448  201383            무이자쿠첸압력밥솥 10인용
# 38299  2019-12-31 23:40:00   NaN  100448  201384             무이자쿠첸압력밥솥 6인용
# 38301  2020-01-01 00:00:00    20  100448  201383            무이자쿠첸압력밥솥 10인용
# 38303  2020-01-01 00:00:00   NaN  100448  201384             무이자쿠첸압력밥솥 6인용
#
#       상품군    판매단가       취급액
# 46     가전  489000  19123000
# ...

# %%
일시불=performance[performance['상품명'].str.contains('일시불' or'(일시불)')]
일시불
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                        상품명  \
# 45     2019-01-01 20:00:00    20  100150  200533             일시불 LG 통돌이 세탁기
# 47     2019-01-01 20:20:00    20  100150  200533             일시불 LG 통돌이 세탁기
# 49     2019-01-01 20:40:00    20  100150  200533             일시불 LG 통돌이 세탁기
# 80     2019-01-02 10:00:00    20  100448  202098  일시불 쿠첸 풀스텐 압력밥솥 10인용 (A1)
# 82     2019-01-02 10:00:00   NaN  100448  202100    일시불 쿠첸 풀스텐 압력밥솥 6인용(A1)
# ...                    ...   ...     ...     ...                        ...
# 38296  2019-12-31 23:20:00   NaN  100448  201391              일시불쿠첸압력밥솥 6인용
# 38298  2019-12-31 23:40:00   NaN  100448  201390             일시불쿠첸압력밥솥 10인용
# 38300  2019-12-31 23:40:00   NaN  100448  201391              일시불쿠첸압력밥솥 6인용
# 38302  2020-01-01 00:00:00   NaN  100448  201390             일시불쿠첸압력밥솥 10인용
# 38304  2020-01-01 00:00:00   NaN  100448  201391              일시불쿠첸압력밥솥 6인용
#
#       상품군    판매단가        취급액
# ...

# %%
#테이트

테이트=performance[performance['상품명'].str.contains('테이트')]
테이트

#성별에 따른 상품명 차이
# Out:
#                       방송일시 노출(분)    마더코드    상품코드              상품명 상품군   판매단가  \
# 1      2019-01-01 06:00:00    20  100346  201072    테이트 남성 셀린니트3종  의류  39900
# 2      2019-01-01 06:00:00   NaN  100346  201079    테이트 여성 셀린니트3종  의류  39900
# 3      2019-01-01 06:20:00    20  100346  201072    테이트 남성 셀린니트3종  의류  39900
# 4      2019-01-01 06:20:00   NaN  100346  201079    테이트 여성 셀린니트3종  의류  39900
# 5      2019-01-01 06:40:00    20  100346  201072    테이트 남성 셀린니트3종  의류  39900
# ...                    ...   ...     ...     ...              ...  ..    ...
# 31708  2019-10-26 15:00:00   NaN  100346  201080  테이트 여성 오가닉 약기모티  의류  69900
# 31709  2019-10-26 15:20:00    20  100346  201073  테이트 남성 오가닉 약기모티  의류  69900
# 31710  2019-10-26 15:20:00   NaN  100346  201080  테이트 여성 오가닉 약기모티  의류  69900
# 31711  2019-10-26 15:40:00    20  100346  201073  테이트 남성 오가닉 약기모티  의류  69900
# 31712  2019-10-26 15:40:00   NaN  100346  201080  테이트 여성 오가닉 약기모티  의류  69900
#
#             취급액
# 1       2099000
# ...

# %%
#테이트 소분류

tate_cate=테이트
tate_cate['상품명']=tate_cate['상품명'].str.replace('테이트','')
tate_cate=tate_cate.drop_duplicates(['상품명'])
tate_cate.sort_values(by=['상품코드'],axis=0)

(201069~201083)

#공통적으로 성별의 차이에 따라 7씩 차이가 난다. 여성이 남성보다 상품코드가 7씩 더 크다
#상품코드 2010까지 동일
#남성부터 쭉 코드 부여를 하고, 그 다음부터 순서대로 여성의 코등
#테이트: 7종류
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                       방송일시 노출(분)    마더코드    상품코드           상품명 상품군   판매단가  \
# 6787   2019-03-11 00:20:00   NaN  100346  201069   남성 SS 트렌치재킷  의류  69900
# 903    2019-01-11 07:00:00    20  100346  201070    남성 기모티셔츠6종  의류  39900
# 13743  2019-05-11 07:00:00    20  100346  201071   남성 모달 티셔츠5종  의류  59900
# 1      2019-01-01 06:00:00    20  100346  201072     남성 셀린니트3종  의류  39900
# 31707  2019-10-26 15:00:00    20  100346  201073   남성 오가닉 약기모티  의류  69900
# 11972  2019-04-26 01:00:00    20  100346  201075   남성 오가닉티셔츠6종  의류  69000
# ...

# %%
#오모떼 여성 속옷?
오모떼=performance[performance['상품명'].str.contains('오모떼')]
오모떼_cate=오모떼
오모떼_cate['상품명']=오모떼_cate['상품명'].str.replace('[완벽더블]','')
오모떼_cate=오모떼_cate.drop_duplicates(['상품명'])
오모떼_cate.sort_values(by=['상품코드'],axis=0)

#200967~200990
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                       방송일시 노출(분)    마더코드    상품코드                        상품명  \
# 36197  2019-12-10 13:20:00    20  100302  200967    []오모떼 모달 웜 이너웨어 3세트+3세트
# 24     2019-01-01 13:00:00    30  100305  200970   오모떼 360도 텐션업 레이스 패키지 시즌4
# 26012  2019-09-03 00:00:00    30  100305  200971   오모떼 360도 텐션업 레이스 패키지 시즌5
# 18164  2019-06-20 07:00:00    30  100306  200972          오모떼 데오 쿨 란쥬쉐이퍼 8종
# 34757  2019-11-26 23:00:00    20  100307  200973         오모떼 드레스핏 웜 쉐이퍼 패키지
# 7      2019-01-01 07:00:00    20  100305  200974           오모떼 레이스 파운데이션 브라
# ...

# %%
performance_wo_eco=performance

# %%
#무이자/일시불/
eco=['(렌탈)','일시불','무이자','(렌탈)','직매입','(무이자)','(무)','파격가',
     '(도냄)일시불','(도냄)무이자','2세트','(직매입)','국내산','국내제작','1세트','(일시불)','국내제조','초특가','[일시불]']

# %%
'''
실패
#정규식으로 아래 문자열을 데이터프레임에서 삭제하고/ 그렇다면 맨 처음에 나오는 것이 브랜드 이름이 될 것 같다
import re
eco_2=performance_wo_eco[performance_wo_eco['상품명'].str.contains('(렌탈)'or'일시불'or'무이자'or'(렌탈)'or'직매입'or
     '(도냄)일시불'or'(도냄)무이자'or'2세트'or'(직매입)'or'국내산'or'국내제작'or'1세트'or'(일시불)'or'국내제조'or'초특가')]
eco_2
'''
# Out:
# "\n실패\n#정규식으로 아래 문자열을 데이터프레임에서 삭제하고/ 그렇다면 맨 처음에 나오는 것이 브랜드 이름이 될 것 같다\nimport re\neco_2=performance_wo_eco[performance_wo_eco['상품명'].str.contains('(렌탈)'or'일시불'or'무이자'or'(렌탈)'or'직매입'or\n     '(도냄)일시불'or'(도냄)무이자'or'2세트'or'(직매입)'or'국내산'or'국내제작'or'1세트'or'(일시불)'or'국내제조'or'초특가')]\neco_2\n"

# %%
performance_wo_eco['상품명']=performance_wo_eco['상품명'].replace(eco,'')
performance_wo_eco
# Out:
#                       방송일시 노출(분)    마더코드    상품코드             상품명 상품군    판매단가  \
# 1      2019-01-01 06:00:00    20  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 2      2019-01-01 06:00:00   NaN  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 3      2019-01-01 06:20:00    20  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 4      2019-01-01 06:20:00   NaN  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 5      2019-01-01 06:40:00    20  100346  201072   테이트 남성 셀린니트3종  의류   39900
# ...                    ...   ...     ...     ...             ...  ..     ...
# 38300  2019-12-31 23:40:00   NaN  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
# 38301  2020-01-01 00:00:00    20  100448  201383  무이자쿠첸압력밥솥 10인용  주방  178000
# 38302  2020-01-01 00:00:00   NaN  100448  201390  일시불쿠첸압력밥솥 10인용  주방  168000
# 38303  2020-01-01 00:00:00   NaN  100448  201384   무이자쿠첸압력밥솥 6인용  주방  158000
# 38304  2020-01-01 00:00:00   NaN  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
#
#              취급액
# 1        2099000
# ...

# %%
items=list(performance_wo_eco['상품명'])

# %%
com_names=list()
for i in range(len(items)):
    temp=items[i].split()
    com_names.append(temp[0])
print(com_names)
# Out:
# ['테이트', '테이트', '테이트', '테이트', '테이트', '테이트', '오모떼', '오모떼', '오모떼', 'CERINI', 'CERINI', 'CERINI', '보코', '보코', '보코', 'CERINI', 'CERINI', 'CERINI', '크로커다일', '크로커다일', '에코라믹', '에코라믹', '에코라믹', '오모떼', '오모떼', '그렉노먼', '그렉노먼', '그렉노먼', '그렉노먼', '뽕셰프', '뽕셰프', '뽕셰프', '국내산', '국내산', '멋진밥상', '비버리힐스폴로클럽', '비버리힐스폴로클럽', '비버리힐스폴로클럽', '우리바다', '우리바다', '우리바다', '푸마', '푸마', '푸마', '일시불', '무이자', '일시불', '무이자', '일시불', '무이자', '마리노블', '마리노블', '마리노블', '헤스티지', '헤스티지', '로베르타', '로베르타', '로베르타', '그렉노먼', '그렉노먼', '그렉노먼', '그렉노먼', '그렉노먼', '그렉노먼', '레이프릴', '레이프릴', '레이프릴', '벨라홈', '벨라홈', '벨라홈', '(직매입)', '(직매입)', '(직매입)', '오모떼', '오모떼', '오모떼', 'NNF', 'NNF', 'NNF', '일시불', '무이자', '일시불', '무이자', '일시불', '무이자', '일시불', '무이자', '일시불', '무이자', '일시불', '무이자', '헤스티지', '헤스티지', '무이자', '일시불', '무이자', '일시불', '무이자', '일시불', '무이자', '일시불', '무이자', '일시불', '무이자', '일시불', '하늘내린', '하늘내린', '하늘내린', '오모떼', '오모떼', '안동간고등어', '안동간고등어', '안동간고등어', 'SPC삼립', 'SPC삼립', 'SPC삼립', 'SPC삼립', 'SPC삼립', 'SPC삼립', '바다먹자', '바다먹자', '바다먹자', '키친플라워', '키친플라워', '키친플라워', '피시원', '피시원', '피시원'
# ...

# %%
com_names=set(com_names)
com_names=list(com_names)
print(com_names)
# Out:
# ['임성근의', '(도냄)일시불', 'AAA', '(직매입)', '쿠쿠', '푸마', '(일)[한샘]', '메디아글램', '세인트스코트', '블루콤', '(일시불)엘렌실라&코즈미', '쿠미투니카', '[바다원]', '시스마르스', '거미손', '5세트', '셀렉프로', '아이넥스', '(무)보루네오', '릴리젼', '김정문의', '1+1보국미니히터(화이트+레드)BKH-1083P', '파로마', '(일)삼익가구', '바로바로', '궁중', '오델로', '레노마', '(a4)팽현숙의', '[K-SWISS]', 'LG전자', '바다먹자', '뱅뱅', '청정수산', '일시불[가이거]', '영산포숙성', '(일)4인용', 'D)LG생활건강', '창녕', '(무)100%리얼착즙석류', '스칸디나비아', '레드캠프', '시크릿', '에르나벨', '[슬로푸드]', '트레스패스', '코펜하겐럭스', 'AAB의', '[수협]', '초특가)에버라스트', '세균싹', '레이프릴', '몬테밀라노', '(1등급)221L_딤채김치냉장고(LDL22DHWJJ)', '아주아', '오가닉뷰티', '안국루테인', '한일', '피시원', '[안드레아바나]리얼카이만', '달바', '로이몬스터', '일)한샘', '(점보특대형)일월', '키친플라워', '일)자미코코', '킹스스파', '에델코첸', '크리스티나앤코', '뉴욕맘', '자올', '(퀸+퀸)일월', '이동수골프', '"', '[실속패키지]레스트업', '[광동제약]', '종근당건강', '[라쉬반］FC바로셀로나', '스피드랙', '올바로', '어반시크릿', '(일)3인용', '가)세렌셉템버', '이봉원', 'BBC&IZUMI', '바바코코', '키친아트', '(무)[안드레아바나]리얼카이만', '피부약방', '네페르티티', '[EXR]', '초특가', '제주갈치+참조기세트', '(무)', '통뼈', '티젠', '뉴웨이', '제주갈치고등어구이세트', 'CERINI', 'USPA화이트라벨', '헤스티지', '바두기', '[디즈니]', '르까프', 
# ...

# %%
com_names in

# %%
def is_not_com(List):
    for i in range(len(List)):
        if (List[i]=='(렌탈)') or(List[i]=='일시불') or (List[i]=='무이자') or (List[i]=='(렌탈)'):
            del List[i]
        elif (List[i]=='직매입')or (List[i]=='(도냄)일시불') or (List[i]=='(도냄)무이자') or (List[i]=='2세트'):
            del List[i]
        elif (List[i]=='(직매입)') or (List[i]=='국내산') or(List[i]=='국내제작') or (List[i]=='1세트'):
            del List[i]
        elif (List[i]=='(일시불)') or (List[i]=='국내제조') or (List[i]=='초특가'):
            del List[i]
        return List

# %%
#추출한 브랜드/ 데이터 프레임상 일치하는 부분 있으면 새로운 열 만들어서 브랜드 따로 저장

# %%
# 브랜드별 데이터 프레임 만들고/ 상품코드 분류하기

# %%
# 브랜드별로 다 분류해서 상품코드 해보기

# %%
#상품명 대 상품코드

tate_code=tate_cate.groupby(['상품명'])['상품코드'].mean()
tate_code=pd.DataFrame(tate_code)
tate_code
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-23-eb9f78368574> in <module>
#       1 #상품명 대 상품코드
#       2
# ----> 3 tate_code=tate_cate.groupby(['상품명'])['상품코드'].mean()
#       4 tate_code=pd.DataFrame(tate_code)
#       5 tate_code
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1392             "mean",
#    1393             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
# -> 1394             numeric_only=numeric_only,
#    1395         )
#    1396
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1047
#    1048         if len(output) == 0:
# -> 1049             raise DataError("No numeric types to aggregate")
#    1050
#    1051         return self._wrap_aggregated_output(output)
#
# ...

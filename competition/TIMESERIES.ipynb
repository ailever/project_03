# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./version09.csv')
time = pd.read_excel('./(changed data)2020 빅콘테스트 데이터분석분야-챔피언리그_2019년 실적데이터_v1_200818.xlsx')

# %%
del data['Unnamed: 0']
# del time['Unnamed: 0']

# %%
time
# Out:
#       NS Shop+ 2019.01.01~12.31 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                          방송일시      노출(분)       마더코드       상품코드
# 1           2019-01-01 06:00:00         20     100346     201072
# 2           2019-01-01 06:00:00        NaN     100346     201079
# 3           2019-01-01 06:20:00         20     100346     201072
# 4           2019-01-01 06:20:00        NaN     100346     201079
# ...                         ...        ...        ...        ...
# 38305       2020-01-01 00:20:00         20     100073     200196
# 38306       2020-01-01 00:40:00         20     100073     200196
# 38307       2020-01-01 01:00:00         20     100073     200196
# 38308       2020-01-01 01:20:00         20     100490     201478
# 38309       2020-01-01 01:40:00    17.1667     100490     201478
#
#                      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0                           상품명        상품군       판매단가        취급액
# ...

# %%
time.columns = ['방송일시', '노출(분)', '마더코드', '상품코드', '상품명', '상품군', '판매단가', '취급액']

time = time.drop([0])

# %%
indexing = list(range(38309))

time.index = indexing

time
# Out:
#                       방송일시    노출(분)    마더코드    상품코드                       상품명  \
# 0      2019-01-01 06:00:00       20  100346  201072             테이트 남성 셀린니트3종
# 1      2019-01-01 06:00:00      NaN  100346  201079             테이트 여성 셀린니트3종
# 2      2019-01-01 06:20:00       20  100346  201072             테이트 남성 셀린니트3종
# 3      2019-01-01 06:20:00      NaN  100346  201079             테이트 여성 셀린니트3종
# 4      2019-01-01 06:40:00       20  100346  201072             테이트 남성 셀린니트3종
# ...                    ...      ...     ...     ...                       ...
# 38304  2020-01-01 00:20:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험(1912)
# 38305  2020-01-01 00:40:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험(1912)
# 38306  2020-01-01 01:00:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험(1912)
# 38307  2020-01-01 01:20:00       20  100490  201478        더케이 예다함 상조서비스(티포트)
# 38308  2020-01-01 01:40:00  17.1667  100490  201478        더케이 예다함 상조서비스(티포트)
#
#       상품군   판매단가      취급액
# ...

# %%
data['방송일시'] = time['방송일시']

# %%
import datetime as dt

# df['Birth'] = pd.to_datetime(df['Birth'], format='%Y-%m-%d %H:%M:%S', errors='raise')


data['방송일시'] = pd.to_datetime(data['방송일시'], format = '%Y-%m-%d %H:%M:%S', errors = 'raise')

# %%
plt.plot(data['취급액'])
# plt.legend(loc=1)

plt.show()

# %%
# data.astype('float')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# data_ts = data.timeseries
# data = data.timeseries

result = seasonal_decompose(data['취급액'].values, freq = 365)


plt.rcParams['figure.figsize'] = [24, 16]
result.plot()
plt.show()
# Out:
# <ipython-input-20-25de698c09b6>:4: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   result = seasonal_decompose(data['취급액'].values, freq = 365)

# %%
result = seasonal_decompose(data['취급액'].values, freq = 1)


plt.rcParams['figure.figsize'] = [24, 16]
result.plot()
plt.show()
# Out:
# <ipython-input-21-d55c06f4a065>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   result = seasonal_decompose(data['취급액'].values, freq = 1)

# %%
result = seasonal_decompose(data['취급액'].values, freq = 12)


plt.rcParams['figure.figsize'] = [24, 16]
result.plot()
plt.show()
# Out:
# <ipython-input-22-cbc8987d9f55>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   result = seasonal_decompose(data['취급액'].values, freq = 12)

# %%
result = seasonal_decompose(data['취급액'].values, freq = 30)


plt.rcParams['figure.figsize'] = [24, 16]
result.plot()
plt.show()
# Out:
# <ipython-input-23-a8d665d6a1ba>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   result = seasonal_decompose(data['취급액'].values, freq = 30)

# %%
result = seasonal_decompose(data['취급액'].values, freq = 60)


plt.rcParams['figure.figsize'] = [24, 16]
result.plot()
plt.show()
# Out:
# <ipython-input-24-08fb8aa8a194>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   result = seasonal_decompose(data['취급액'].values, freq = 60)

# %%
result = seasonal_decompose(data['취급액'].values, freq = 90)


plt.rcParams['figure.figsize'] = [24, 16]
result.plot()
plt.show()
# Out:
# <ipython-input-25-45de2eb8ceab>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   result = seasonal_decompose(data['취급액'].values, freq = 90)

# %% [markdown]
# # 참고사항

# %%
"""length = 400
x = np.sin(np.arange(length)) * 10 + np.random.randn(length)
df = pd.DataFrame(data=x, index=pd.date_range(start=dt.datetime(2015, 1, 1), periods=length, freq='w'), columns=['value'])


decomp = sm.tsa.seasonal_decompose(df, freq=52)

여기서 freq=52인 이유는 df를 정의할 때 freq='w', 즉 week로 설정해줬기 때문에 1년에 52주

(https://stackoverflow.com/questions/34494780/time-series-analysis-unevenly-spaced-measures-pandas-statsmodels)

"""

# %%
df
# Out:
#                 value
# 2015-01-04   0.150095
# 2015-01-11   6.762256
# 2015-01-18  10.359942
# 2015-01-25   3.031814
# 2015-02-01  -7.493690
# ...               ...
# 2022-07-31  -6.133038
# 2022-08-07   1.392295
# 2022-08-14   8.944438
# 2022-08-21   8.394346
# 2022-08-28  -0.864496
#
# [400 rows x 1 columns]

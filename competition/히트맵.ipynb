# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import matplotlib as pl

# %%
performance=pd.read_csv('C:/Users/user/Downloads/version14.csv')

# %%
performance
# Out:
#         Unnamed: 0            방송일시  노출(분)    마더코드    상품코드   상품명  상품군  브랜드  \
# 0                0  20190101060000     20  100346  201072  1592    7  373
# 1                1  20190101060000     20  100346  201079  1598    7  373
# 2                2  20190101060100     20  100346  201072  1592    7  373
# 3                3  20190101060100     20  100346  201079  1598    7  373
# 4                4  20190101060200     20  100346  201072  1592    7  373
# ...            ...             ...    ...     ...     ...   ...  ...  ...
# 719340      782887  20200101001800     20  100448  201391  1416   10  362
# 719341      782888  20200101001900     20  100448  201383   822   10  362
# 719342      782889  20200101001900     20  100448  201390  1415   10  362
# 719343      782890  20200101001900     20  100448  201384   823   10  362
# 719344      782891  20200101001900     20  100448  201391  1416   10  362
#
#           판매단가     유동인구       PM10  PM25      취급액
# ...

# %%
font_name = pl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
plt.rc('font', family=font_name)

# %%
performance.drop('Unnamed: 0',axis=1,inplace=True)
performance
# Out:
#                   방송일시  노출(분)    마더코드    상품코드   상품명  상품군  브랜드    판매단가  \
# 0       20190101060000     20  100346  201072  1592    7  373   39900
# 1       20190101060000     20  100346  201079  1598    7  373   39900
# 2       20190101060100     20  100346  201072  1592    7  373   39900
# 3       20190101060100     20  100346  201079  1598    7  373   39900
# 4       20190101060200     20  100346  201072  1592    7  373   39900
# ...                ...    ...     ...     ...   ...  ...  ...     ...
# 719340  20200101001800     20  100448  201391  1416   10  362  148000
# 719341  20200101001900     20  100448  201383   822   10  362  178000
# 719342  20200101001900     20  100448  201390  1415   10  362  168000
# 719343  20200101001900     20  100448  201384   823   10  362  158000
# 719344  20200101001900     20  100448  201391  1416   10  362  148000
#
#            유동인구       PM10  PM25      취급액
# 0       8123838  42.650000  29.0   104950
# ...

# %%
plt.figure(figsize=(25,20))
sns.heatmap(performance.corr(),annot = True,cmap='coolwarm')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#상관관계 높은 것: 마더코드와 상품코드: 90% 이상
#브랜드와 상품명도 0.47의 상관관계
#브랜드와 상품군 0.35의 상관관계

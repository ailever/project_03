# %%
import pandas as pd


performance = pd.read_excel('C:/Users/user/Downloads/01_제공데이터/2020 빅콘테스트 데이터분석분야-챔피언리그_2019년 실적데이터_v1_200818.xlsx')
performance.columns=['방송일시', '노출(분)', '마더코드', '상품코드', '상품명', '상품군', '판매단가', '취급액']

performance = performance.drop([0])
performance
# Out:
#                       방송일시    노출(분)    마더코드    상품코드                       상품명  \
# 1      2019-01-01 06:00:00       20  100346  201072             테이트 남성 셀린니트3종
# 2      2019-01-01 06:00:00      NaN  100346  201079             테이트 여성 셀린니트3종
# 3      2019-01-01 06:20:00       20  100346  201072             테이트 남성 셀린니트3종
# 4      2019-01-01 06:20:00      NaN  100346  201079             테이트 여성 셀린니트3종
# 5      2019-01-01 06:40:00       20  100346  201072             테이트 남성 셀린니트3종
# ...                    ...      ...     ...     ...                       ...
# 38305  2020-01-01 00:20:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험(1912)
# 38306  2020-01-01 00:40:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험(1912)
# 38307  2020-01-01 01:00:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험(1912)
# 38308  2020-01-01 01:20:00       20  100490  201478        더케이 예다함 상조서비스(티포트)
# 38309  2020-01-01 01:40:00  17.1667  100490  201478        더케이 예다함 상조서비스(티포트)
#
#       상품군   판매단가      취급액
# ...

# %%
#성별 분류
#남자
male=performance[performance['상품명'].str.contains('남성' or'남자')]
male
# Out:
#                       방송일시 노출(분)    마더코드    상품코드  \
# 1      2019-01-01 06:00:00    20  100346  201072
# 3      2019-01-01 06:20:00    20  100346  201072
# 5      2019-01-01 06:40:00    20  100346  201072
# 10     2019-01-01 08:00:00    20  100808  202377
# 11     2019-01-01 08:20:00    20  100808  202377
# ...                    ...   ...     ...     ...
# 38185  2019-12-30 20:40:00    20  100074  200199
# 38186  2019-12-30 21:00:00    20  100074  200199
# 38217  2019-12-31 08:20:00    20  100390  201261
# 38219  2019-12-31 08:40:00    20  100390  201261
# 38221  2019-12-31 09:00:00    20  100390  201261
#
#                                  상품명  상품군   판매단가       취급액
# 1                      테이트 남성 셀린니트3종   의류  39900   2099000
# 3                      테이트 남성 셀린니트3종   의류  39900   3262000
# 5                      테이트 남성 셀린니트3종   의류  39900   6672000
# 10     CERINI by PAT 남성 소프트 기모 릴렉스팬츠   의류  59900  16133000
# 11     CERINI by PAT 남성 소프트 기모 릴렉스팬츠   의류  59900  30061000
# ...

# %%
#여자
fem=performance[performance['상품명'].str.contains('여성' or'여자')]
fem
# Out:
#                       방송일시 노출(분)    마더코드    상품코드  \
# 2      2019-01-01 06:00:00   NaN  100346  201079
# 4      2019-01-01 06:20:00   NaN  100346  201079
# 6      2019-01-01 06:40:00   NaN  100346  201079
# 27     2019-01-01 14:00:00   NaN  100377  201226
# 29     2019-01-01 14:30:00   NaN  100377  201226
# ...                    ...   ...     ...     ...
# 38063  2019-12-29 08:40:00   NaN  100390  201264
# 38065  2019-12-29 09:00:00   NaN  100390  201264
# 38218  2019-12-31 08:20:00   NaN  100390  201264
# 38220  2019-12-31 08:40:00   NaN  100390  201264
# 38222  2019-12-31 09:00:00   NaN  100390  201264
#
#                                  상품명 상품군    판매단가       취급액
# 2                      테이트 여성 셀린니트3종  의류   39900   4371000
# 4                      테이트 여성 셀린니트3종  의류   39900   6955000
# 6                      테이트 여성 셀린니트3종  의류   39900   9337000
# 27               그렉노먼 여성 구스다운 롱 벤치코트  의류  119000  20841000
# 29               그렉노먼 여성 구스다운 롱 벤치코트  의류  119000  47294000
# ...

# %%
#결제방식

무이자=performance[performance['상품명'].str.contains('무이자' or'(무이자)')]
무이자
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                       상품명  \
# 46     2019-01-01 20:00:00   NaN  100150  200465            무이자 LG 통돌이 세탁기
# 48     2019-01-01 20:20:00   NaN  100150  200465            무이자 LG 통돌이 세탁기
# 50     2019-01-01 20:40:00   NaN  100150  200465            무이자 LG 통돌이 세탁기
# 81     2019-01-02 10:00:00   NaN  100448  202093  무이자 쿠첸 풀스텐 압력밥솥 10인용(A1)
# 83     2019-01-02 10:00:00   NaN  100448  202095   무이자 쿠첸 풀스텐 압력밥솥 6인용(A1)
# ...                    ...   ...     ...     ...                       ...
# 38295  2019-12-31 23:20:00   NaN  100448  201384             무이자쿠첸압력밥솥 6인용
# 38297  2019-12-31 23:40:00    20  100448  201383            무이자쿠첸압력밥솥 10인용
# 38299  2019-12-31 23:40:00   NaN  100448  201384             무이자쿠첸압력밥솥 6인용
# 38301  2020-01-01 00:00:00    20  100448  201383            무이자쿠첸압력밥솥 10인용
# 38303  2020-01-01 00:00:00   NaN  100448  201384             무이자쿠첸압력밥솥 6인용
#
#       상품군    판매단가       취급액
# 46     가전  489000  19123000
# ...

# %%
일시불=performance[performance['상품명'].str.contains('일시불' or'(일시불)')]
일시불
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                        상품명  \
# 45     2019-01-01 20:00:00    20  100150  200533             일시불 LG 통돌이 세탁기
# 47     2019-01-01 20:20:00    20  100150  200533             일시불 LG 통돌이 세탁기
# 49     2019-01-01 20:40:00    20  100150  200533             일시불 LG 통돌이 세탁기
# 80     2019-01-02 10:00:00    20  100448  202098  일시불 쿠첸 풀스텐 압력밥솥 10인용 (A1)
# 82     2019-01-02 10:00:00   NaN  100448  202100    일시불 쿠첸 풀스텐 압력밥솥 6인용(A1)
# ...                    ...   ...     ...     ...                        ...
# 38296  2019-12-31 23:20:00   NaN  100448  201391              일시불쿠첸압력밥솥 6인용
# 38298  2019-12-31 23:40:00   NaN  100448  201390             일시불쿠첸압력밥솥 10인용
# 38300  2019-12-31 23:40:00   NaN  100448  201391              일시불쿠첸압력밥솥 6인용
# 38302  2020-01-01 00:00:00   NaN  100448  201390             일시불쿠첸압력밥솥 10인용
# 38304  2020-01-01 00:00:00   NaN  100448  201391              일시불쿠첸압력밥솥 6인용
#
#       상품군    판매단가        취급액
# ...

# %%
#테이트

테이트=performance[performance['상품명'].str.contains('테이트')]
테이트

#성별에 따른 상품명 차이
# Out:
#                       방송일시 노출(분)    마더코드    상품코드              상품명 상품군   판매단가  \
# 1      2019-01-01 06:00:00    20  100346  201072    테이트 남성 셀린니트3종  의류  39900
# 2      2019-01-01 06:00:00   NaN  100346  201079    테이트 여성 셀린니트3종  의류  39900
# 3      2019-01-01 06:20:00    20  100346  201072    테이트 남성 셀린니트3종  의류  39900
# 4      2019-01-01 06:20:00   NaN  100346  201079    테이트 여성 셀린니트3종  의류  39900
# 5      2019-01-01 06:40:00    20  100346  201072    테이트 남성 셀린니트3종  의류  39900
# ...                    ...   ...     ...     ...              ...  ..    ...
# 31708  2019-10-26 15:00:00   NaN  100346  201080  테이트 여성 오가닉 약기모티  의류  69900
# 31709  2019-10-26 15:20:00    20  100346  201073  테이트 남성 오가닉 약기모티  의류  69900
# 31710  2019-10-26 15:20:00   NaN  100346  201080  테이트 여성 오가닉 약기모티  의류  69900
# 31711  2019-10-26 15:40:00    20  100346  201073  테이트 남성 오가닉 약기모티  의류  69900
# 31712  2019-10-26 15:40:00   NaN  100346  201080  테이트 여성 오가닉 약기모티  의류  69900
#
#             취급액
# 1       2099000
# ...

# %%
#테이트 소분류

tate_cate=테이트
tate_cate['상품명']=tate_cate['상품명'].str.replace('테이트','')
tate_cate=tate_cate.drop_duplicates(['상품명'])
tate_cate.sort_values(by=['상품코드'],axis=0)

#(201069~201083)

#공통적으로 성별의 차이에 따라 7씩 차이가 난다. 여성이 남성보다 상품코드가 7씩 더 크다
#상품코드 2010까지 동일
#남성부터 쭉 코드 부여를 하고, 그 다음부터 순서대로 여성의 코등
#테이트: 7종류
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                       방송일시 노출(분)    마더코드    상품코드           상품명 상품군   판매단가  \
# 6787   2019-03-11 00:20:00   NaN  100346  201069   남성 SS 트렌치재킷  의류  69900
# 903    2019-01-11 07:00:00    20  100346  201070    남성 기모티셔츠6종  의류  39900
# 13743  2019-05-11 07:00:00    20  100346  201071   남성 모달 티셔츠5종  의류  59900
# 1      2019-01-01 06:00:00    20  100346  201072     남성 셀린니트3종  의류  39900
# 31707  2019-10-26 15:00:00    20  100346  201073   남성 오가닉 약기모티  의류  69900
# 11972  2019-04-26 01:00:00    20  100346  201075   남성 오가닉티셔츠6종  의류  69000
# ...

# %%
#오모떼 여성 속옷?
오모떼=performance[performance['상품명'].str.contains('오모떼')]
오모떼_cate=오모떼
오모떼_cate['상품명']=오모떼_cate['상품명'].str.replace('[완벽더블]','')
오모떼_cate=오모떼_cate.drop_duplicates(['상품명'])
오모떼_cate.sort_values(by=['상품코드'],axis=0)

#200967~200990
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                       방송일시 노출(분)    마더코드    상품코드                        상품명  \
# 36197  2019-12-10 13:20:00    20  100302  200967    []오모떼 모달 웜 이너웨어 3세트+3세트
# 24     2019-01-01 13:00:00    30  100305  200970   오모떼 360도 텐션업 레이스 패키지 시즌4
# 26012  2019-09-03 00:00:00    30  100305  200971   오모떼 360도 텐션업 레이스 패키지 시즌5
# 18164  2019-06-20 07:00:00    30  100306  200972          오모떼 데오 쿨 란쥬쉐이퍼 8종
# 34757  2019-11-26 23:00:00    20  100307  200973         오모떼 드레스핏 웜 쉐이퍼 패키지
# 7      2019-01-01 07:00:00    20  100305  200974           오모떼 레이스 파운데이션 브라
# ...

# %%
performance_wo_eco=performance

# %%
#무이자/일시불/
'''
spe=['(',')','[',']']
eco=['(렌탈)','일시불','무이자','(렌탈)','직매입','(무이자)','(무)','파격가','[12.5m',
     '(도냄)일시불','(도냄)무이자','2세트','(직매입)','국내산','국내제작','1세트','(일시불)','국내제조','초특가','[일시불]',
    '자연산','(일)','(싱글+싱글)','(퀸+싱글)','(킹+싱글)','(중형)','(퀸+퀸)']
'''
# Out:
# "\nspe=['(',')','[',']']\neco=['(렌탈)','일시불','무이자','(렌탈)','직매입','(무이자)','(무)','파격가','[12.5m',\n     '(도냄)일시불','(도냄)무이자','2세트','(직매입)','국내산','국내제작','1세트','(일시불)','국내제조','초특가','[일시불]',\n    '자연산','(일)','(싱글+싱글)','(퀸+싱글)','(킹+싱글)','(중형)','(퀸+퀸)']\n"

# %%
'''
실패
#정규식으로 아래 문자열을 데이터프레임에서 삭제하고/ 그렇다면 맨 처음에 나오는 것이 브랜드 이름이 될 것 같다
import re
eco_2=performance_wo_eco[performance_wo_eco['상품명'].str.contains('(렌탈)'or'일시불'or'무이자'or'(렌탈)'or'직매입'or
     '(도냄)일시불'or'(도냄)무이자'or'2세트'or'(직매입)'or'국내산'or'국내제작'or'1세트'or'(일시불)'or'국내제조'or'초특가')]
eco_2
'''
# Out:
# "\n실패\n#정규식으로 아래 문자열을 데이터프레임에서 삭제하고/ 그렇다면 맨 처음에 나오는 것이 브랜드 이름이 될 것 같다\nimport re\neco_2=performance_wo_eco[performance_wo_eco['상품명'].str.contains('(렌탈)'or'일시불'or'무이자'or'(렌탈)'or'직매입'or\n     '(도냄)일시불'or'(도냄)무이자'or'2세트'or'(직매입)'or'국내산'or'국내제작'or'1세트'or'(일시불)'or'국내제조'or'초특가')]\neco_2\n"

# %%
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('(','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('[','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace(')','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace(']','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('+','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('무이자','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('일시불','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('자연산','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('렌탈','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('도냄','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('직매입','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('국내산','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('국내제작','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('초특가','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('싱글','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('퀸','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('중형','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('킹','')
#performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('이자','')
#performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('시불','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('2019년','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('12.5m','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('기본구성','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('특집','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('3인용','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('프리미엄','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('통뼈','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('가격인하','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('특등급','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('(무)4인용','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('손질','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('완벽더블','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('구성','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('사이즈','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('1세트','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('2세트','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('3세트','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('4세트','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('5세트','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('국내제조','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('파격가','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('"','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('명인','')
performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace('실속','')

# %%
#performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace(spe,'')
#performance_wo_eco['상품명']=performance_wo_eco['상품명'].str.replace(eco,'')
#performance_wo_eco

# %%
무이자=performance_wo_eco[performance_wo_eco['상품명'].str.contains('무이자' or'(무이자)')]
무이자
# Out:
# Empty DataFrame
# Columns: [방송일시, 노출(분), 마더코드, 상품코드, 상품명, 상품군, 판매단가, 취급액]
# Index: []

# %%
items=list(performance_wo_eco['상품명'])

# %%
com_names=list()
for i in range(len(items)):
    temp=items[i].split()
    com_names.append(temp[0])
print(com_names)
# Out:
# ['테이트', '테이트', '테이트', '테이트', '테이트', '테이트', '오모떼', '오모떼', '오모떼', 'CERINI', 'CERINI', 'CERINI', '보코', '보코', '보코', 'CERINI', 'CERINI', 'CERINI', '크로커다일', '크로커다일', '에코라믹', '에코라믹', '에코라믹', '오모떼', '오모떼', '그렉노먼', '그렉노먼', '그렉노먼', '그렉노먼', '뽕셰프', '뽕셰프', '뽕셰프', '갑오징어', '갑오징어', '멋진밥상', '비버리힐스폴로클럽', '비버리힐스폴로클럽', '비버리힐스폴로클럽', '우리바다', '우리바다', '우리바다', '푸마', '푸마', '푸마', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG
# ...

# %%
#com_names.remove('쿠')
com_names.remove('뉴')

# %%
com_names.remove('11')

# %%
if '일월' in com_names:
    print(True)
else:
    print (False)
# Out:
# True

# %%
if '참바다손질낙지100미양념장연포탕육수' in com_names:
    print(True)
else:
    print (False)
# Out:
# False

# %%
if '일월' in com_names:
    print(True)
else:
    print (False)
# Out:
# True

# %%
com_names.remove('무')
com_names.remove('일')
com_names.remove('2019')
com_names.remove('19년')

# %%
com_names[3]
# Out:
# '삼성노트북'

# %%
#com_names.remove('(도냄)일시불')
#com_names.remove('(직매입)')
#com_names.remove('무)')
#com_names.remove('(무)4인용')
#com_names.remove('국내산')
#com_names.remove('[1세트]')
#com_names.remove('파격가')

# %%
com_names
# Out:
# ['일보루네오',
#  'TCOM_바디프랜드',
#  '무모나코사놀',
#  '삼성노트북',
#  '최인선',
#  '쿠',
#  '완도꼬마활전복',
#  '도스문도스',
#  '블랙모어스',
#  '얼리젼',
#  '김정문의',
#  '캐치온',
#  '코치',
#  '바다먹자',
#  '두꺼비',
#  '사운드룩',
#  '천연담아',
#  '특大갑오징어',
#  '페플럼제이',
#  '김병지',
#  '디즈니',
#  '제주농장',
#  '삼성화재',
#  '롯데JTB',
#  '참바다낙지양념장연포탕육수',
#  '센스락무선진공포장기',
#  '점보형일월',
#  '자숙찰골뱅이',
#  '청정수산',
#  '리복',
#  '릴리젼',
#  '종근당건강',
#  '일자미코코',
#  '실리만',
#  '까사마루',
#  '뱅뱅',
#  '한일',
#  '메디아글램',
#  '램프쿡',
#  '헬스리아',
#  '이봉원',
#  '올뉴',
#  '루미테라피',
#  '보몽드',
#  '일4인용',
#  '안드레아바나리얼카이만',
#  '씨엔지코리아',
#  '스팀큐다리미',
#  'a4팽현숙의',
#  '에지리',
#  '구스터',
#  'x',
#  '센스톰알파청소기',
#  '자올',
#  '파시노',
#  '일이누스바스',
#  '아키',
#  '안지',
#  '수련',
#  '뽕셰프',
#  '란체티',
#  '이만기의',
#  '스텔라테일러',
#  '코지마',
#  '바치',
#  '댄스킨',
#  '해피콜엑슬림블렌더',
#  '하동',
#  '영산포숙성홍어회7팩',
#  '무농약레드비트즙',
#  'TCOM_현대해상',
#  '상담접수상품뇌새김',
#  '뉴트리원',
#  '노와',
#  '메시제이',
#  '에펨',
#  '로벤탈',
#  '모즈',
#  '통오징어',
#  '무한샘',
#  '시크릿뮤즈',
#  '농협안심벌꿀',
#  '삼성5도어냉장고',
#  'KF94',
#  '한세트',
#  '헤드',
#  '시크릿',
# ...

# %%
#com_names.remove('ARS10%크로커다일')
#com_names.remove('형')
#com_names.remove('손질')
com_names.remove('19')
#com_names.remove('참바다손질낙지100미양념장연포탕육수')
#com_names.remove('2세트')
#com_names.remove('1세트')
com_names.remove('농협안심벌꿀')
com_names.remove('쿠첸압력밥솥')
#com_names.remove('5세트')
com_names.remove('더블사이즈일월')
com_names.remove('일')
com_names.remove('1등급467L_딤채김치냉장고')
com_names.remove('1등급221L_딤채김치냉장고LDL22DHWJJ')
com_names.remove('파격가')
com_names.remove('무')
com_names.remove('일')
com_names.remove('국내생산')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-363-bef0c33b516b> in <module>
#       9 com_names.remove('쿠첸압력밥솥')
#      10 #com_names.remove('5세트')
# ---> 11 com_names.remove('더블사이즈일월')
#      12 com_names.remove('일')
#      13 com_names.remove('1등급467L_딤채김치냉장고')
#
# ValueError: list.remove(x): x not in list

# %%
if '형' in com_names:
    print(True)
# Out:
# True

# %%
com_names.remove('형')

# %%
com_names.append('딤채')
com_names.append('참바다')

# %%
com_names.append('뉴 클레린')

# %%
com=pd.DataFrame(data={'상품명':com_names})

# %%
com
# Out:
#             상품명
# 0         일보루네오
# 1    TCOM_바디프랜드
# 2        무모나코사놀
# 3         삼성노트북
# 4           최인선
# ..          ...
# 503          LG
# 504        무메리츠
# 505          딤채
# 506         참바다
# 507       뉴 클레린
#
# [508 rows x 1 columns]

# %%
print(com_names)
# Out:
# ['일보루네오', 'TCOM_바디프랜드', '무모나코사놀', '삼성노트북', '최인선', '쿠', '완도꼬마활전복', '도스문도스', '블랙모어스', '얼리젼', '김정문의', '캐치온', '코치', '바다먹자', '두꺼비', '사운드룩', '천연담아', '특大갑오징어', '페플럼제이', '김병지', '디즈니', '제주농장', '삼성화재', '롯데JTB', '참바다낙지양념장연포탕육수', '센스락무선진공포장기', '점보형일월', '자숙찰골뱅이', '청정수산', '리복', '릴리젼', '종근당건강', '일자미코코', '실리만', '까사마루', '뱅뱅', '한일', '메디아글램', '램프쿡', '헬스리아', '이봉원', '올뉴', '루미테라피', '보몽드', '일4인용', '안드레아바나리얼카이만', '씨엔지코리아', '스팀큐다리미', 'a4팽현숙의', '에지리', '구스터', 'x', '센스톰알파청소기', '자올', '파시노', '일이누스바스', '아키', '안지', '수련', '뽕셰프', '란체티', '이만기의', '스텔라테일러', '코지마', '바치', '댄스킨', '해피콜엑슬림블렌더', '하동', '영산포숙성홍어회7팩', '무농약레드비트즙', 'TCOM_현대해상', '상담접수상품뇌새김', '뉴트리원', '노와', '메시제이', '에펨', '로벤탈', '모즈', '통오징어', '무한샘', '시크릿뮤즈', '삼성5도어냉장고', 'KF94', '한세트', '헤드', '시크릿', '경남제약', '오렐리안', '이롬', '레드캠프', '붙이는', '참조기12팩', '알비에로', '히팅맘', '햇', '궁중', '테이트', 'VONIN보닌', '셰프웨이', '델첸', '창녕', '오세득', '살롱클리닉샤이닝', 'ALL', '에버홈', '아가타', '락앤락', '포항구룡포과메기세트', '오가닉뷰티', '참좋은여행', '스칸디나비아', '밸런스파워', '스튜디오럭스', '메이듀', '마모트', '스마트코너', '점보특대형일월', '보코', '까사마루행거', '마이클코어
# ...

# %%
일월=[s for s in com_names if '일월' in s]
일월
# Out:
# ['점보형일월', '점보특대형일월', '더블일월', '일월', '더블더블일월']

# %%
딤채=[s for s in com_names if '딤채' in s]
딤채
# Out:
# ['1등급221L_딤채김치냉장고',
#  '1등급467L_딤채김치냉장고',
#  '467L_딤채김치냉장고',
#  '1등급221L_딤채김치냉장고LDL22DHWJJ',
#  '221L_딤채김치냉장고',
#  '딤채']

# %%
sk=[s for s in com_names if 'SK매직' in s]
sk
# Out:
# ['SK매직', 'SK매직정수기']

# %%
com_names.remove('SK매직정수기')

# %%
삼익=[s for s in com_names if '삼익' in s]
삼익
# Out:
# ['일삼익가구', '무삼익가구']

# %%
#해피콜: 주방 소품 회사
해피콜=[s for s in com_names if '해피콜' in s]
해피콜
# Out:
# ['해피콜엑슬림블렌더', '해피콜IH양면팬', '해피콜']

# %%
휴롬=[s for s in com_names if '휴롬' in s]
휴롬
# Out:
# ['휴롬퀵스퀴저', '휴롬']

# %%
쿠쿠=[s for s in com_names if '쿠쿠' in s]
쿠쿠
# Out:
# ['쿠쿠전기밥솥', '쿠쿠']

# %%
com_names.remove('쿠쿠전기밥솥')

# %%
com_names.remove('휴롬퀵스퀴저')

# %%
한솔=[s for s in com_names if '한솔' in s]
한솔
# Out:
# ['특대한솔', '점보한솔', '대형한솔']

# %%
쿠첸=[s for s in com_names if '쿠첸' in s]
쿠첸
# Out:
# ['쿠첸인버터전자레인지', '쿠첸']

# %%
com_names.remove('쿠첸인버터전자레인지')

# %%
f11=[s for s in com_names if '11' in s]
f11
# Out:
# ['11보국미니히터화이트레드BKH-1083P', '11보국미니히터화이트화이트']

# %%
한샘=[s for s in com_names if '한샘' in s]
한샘
# Out:
# ['무한샘', '일한샘', '한샘']

# %%
인용=[s for s in com_names if '인용' in s]
인용
# Out:
# ['일4인용']

# %%
거창사과=[s for s in com_names if '거창사과' in s]
거창사과
# Out:
# ['더커진거창사과', '거창사과']

# %%
com_names.remove('더커진거창사과')

# %%
크로커다일=[s for s in com_names if '크로커다일' in s]
크로커다일
# Out:
# ['ARS10%크로커다일', '크로커다일']

# %%
com_names.remove('ARS10%크로커다일')

# %%
USPA=[s for s in com_names if 'USPA' in s]
USPA
# Out:
# ['USPA', 'USPA화이트라벨']

# %%
com_names.remove('USPA화이트라벨')

# %%
월시스=[s for s in com_names if 'x' in s]
월시스
# Out:
# ['x']

# %%
if 'x' in com_names:
    print(True)
# Out:
# True

# %%
com_names.remove('x')

# %%
if '월시스' in com_names:
    print(True)

# %%
com_names.append('월시스')

# %%
com_names.remove('맛있는')

# %%
장수=[s for s in com_names if '장수' in s]
장수
# Out:
# ['일장수', '일장수흙침대', '무장수', '무장수흙침대']

# %%
#IH는 인덕션 레인지/ 브랜드 아님
IH=[s for s in com_names if 'IH' in s]
IH
# Out:
# ['해피콜IH양면팬', 'IH']

# %%
TCOM=[s for s in com_names if 'TCOM' in s]
TCOM
# 무형
# Out:
# ['TCOM_바디프랜드',
#  'TCOM_현대해상',
#  'TCOM_라클라우드',
#  'TCOM_아이러너',
#  'TCOM_처브치아보험',
#  'TCOM_관절염',
#  'TCOM_X-RUN']

# %%
명인=[s for s in com_names if '명인' in s]
명인
# Out:
# []

# %%
베스트하임=[s for s in com_names if '베스트' in s]
베스트하임
# Out:
# ['베스트', '베스트하임']

# %%
com_names.remove('베스트하임')
#나중에 베스트하임으로 통일시켜야 함

# %%
올바로=[s for s in com_names if '올바로' in s]
올바로
# Out:
# ['올바로바른자세밴드', '올바로']

# %%
com_names.remove('올바로바른자세밴드')

# %%
이경제=[s for s in com_names if '이경제' in s]
이경제
# Out:
# ['이경제원장의', '이경제의']

# %%
영산포=[s for s in com_names if '영산포' in s]
영산포
# Out:
# ['영산포숙성홍어회7팩', '영산포숙성']

# %%
com_names.remove('영산포숙성홍어회7팩')

# %%
com_names=[x for x in com_names if x not in 인용]

# %%
com_names=[x for x in com_names if x not in 이경제]

# %%
com_names.append('이경제')

# %%
com_names=[x for x in com_names if x not in 장수]

# %%
com_names.append('장수')

# %%
com_names=[x for x in com_names if x not in 한샘]

# %%
com_names=[x for x in com_names if x not in 딤채]

# %%
com_names=[x for x in com_names if x not in 해피콜]

# %%
com_names=[x for x in com_names if x not in 한솔]

# %%
if '한솔' in com_names:
    print(True)

# %%
com_names.append('한솔')

# %%
com_names=[x for x in com_names if x not in 삼익]
com_names=[x for x in com_names if x not in f11]
com_names=[x for x in com_names if x not in IH]

# %%
if '보국' in com_names:
    print (True)
else:
    print(False)
# Out:
# False

# %%
if '햇' in com_names:
    print (True)
else:
    print(False)
# Out:
# True

# %%
if '피시원' in com_names:
    print (True)
else:
    print(False)
# Out:
# True

# %%
if '종근당건강' in com_names:
    print(True)
# Out:
# True

# %%
com_names.remove('단하루')

# %%
if '엘렌실라&코즈미' in com_names:
    print(True)
# Out:
# True

# %%
if 'KF94' in com_names:
    print (True)
else:
    print(False)
# Out:
# True

# %%
com_names.remove('KF94')

# %%
if '엔웰스' in com_names:
    print (True)
else:
    print(False)
# Out:
# False

# %%
com_names.append('엔웰스')

# %%
if '갑오징어' in com_names:
    print (True)
else:
    print(False)
# Out:
# True

# %%
if 'NEW' in com_names:
    print (True)
else:
    print(False)
# Out:
# True

# %%
com_names.remove('NEW') #TS 샴푸인데 잘못 추출

# %%
com_names.append('TS')

# %%
com_names.remove('햇')

# %%
com_names.append('해피콜')

# %%
com_names.append('보국')

# %%
com_names.append('한샘')

# %%
com_names.append('일월')

# %%
com_names.append('딤채')

# %%
com_names.append('삼익가구')

# %%
if '파뷔에' in com_names:
    print(True)
# Out:
# True

# %%
if '해피콜' in com_names:
    print(True)
# Out:
# True

# %%
if '옛날' in com_names:
    print(True)
# Out:
# True

# %%
if '굿프렌드' in com_names:
    print(True)
# Out:
# True

# %%
if '바다먹자' in com_names:
    print(True)
# Out:
# True

# %%
if '쿠' in com_names:
    print(True)
# Out:
# True

# %%
com_names.remove('쿠')

# %%
if 'NNF' in com_names:
    print(True)
# Out:
# True

# %%
if '쿠첸' in com_names:
    print(True)
# Out:
# True

# %%
if '형' in com_names:
    print(True)

# %%
if '국내생산' in com_names:
    print(True)
# Out:
# True

# %%
com_names.remove('국내생산')

# %%
if '파격가' in com_names:
    print(True)

# %%
if '초특가' in com_names:
    print(True)

# %%
if '' in com_names:
    print(True)

# %%
if '국내제조' in com_names:
    print(True)

# %%
if 'IH' in com_names:
    print(True)

# %%
if 'ALL' in com_names:
    print(True)
    
"ALL NEW 파워스윙: 스윙 브랜드"
# Out:
# True
# 'ALL NEW 파워스윙: 스윙 브랜드'

# %%
올=[s for s in com_names if 'ALL' in s]
올
# Out:
# ['ALL']

# %%
뉴=[s for s in com_names if '뉴' in s]
뉴
# Out:
# ['올뉴', '뉴트리원', '뉴웨이', '뉴욕맘', '뉴질랜드', '뉴 클레린']

# %%
'''
올뉴 숀리 스쿼트 머신은 이화에스엠피 브랜드
'''
# Out:
# '\n올뉴 숀리 스쿼트 머신은 이화에스엠피 브랜드\n'

# %%
com_names.append('IH 옛 가마솥 세트')

# %%
#com_names.remove('형')

# %%
if '올리고' in com_names:
    print(True)
# Out:
# True

# %%
if '스텐락' in com_names:
    print(True)

# %%
com_names.append('스텐락')

# %%
com_names
# Out:
# ['일보루네오',
#  'TCOM_바디프랜드',
#  '무모나코사놀',
#  '삼성노트북',
#  '최인선',
#  '완도꼬마활전복',
#  '도스문도스',
#  '블랙모어스',
#  '얼리젼',
#  '김정문의',
#  '캐치온',
#  '코치',
#  '바다먹자',
#  '두꺼비',
#  '사운드룩',
#  '천연담아',
#  '특大갑오징어',
#  '페플럼제이',
#  '김병지',
#  '디즈니',
#  '제주농장',
#  '삼성화재',
#  '롯데JTB',
#  '참바다낙지양념장연포탕육수',
#  '센스락무선진공포장기',
#  '점보형일월',
#  '자숙찰골뱅이',
#  '청정수산',
#  '리복',
#  '릴리젼',
#  '종근당건강',
#  '일자미코코',
#  '실리만',
#  '까사마루',
#  '뱅뱅',
#  '한일',
#  '메디아글램',
#  '램프쿡',
#  '헬스리아',
#  '이봉원',
#  '올뉴',
#  '루미테라피',
#  '보몽드',
#  '안드레아바나리얼카이만',
#  '씨엔지코리아',
#  '스팀큐다리미',
#  'a4팽현숙의',
#  '에지리',
#  '구스터',
#  '센스톰알파청소기',
#  '자올',
#  '파시노',
#  '일이누스바스',
#  '아키',
#  '안지',
#  '수련',
#  '뽕셰프',
#  '란체티',
#  '이만기의',
#  '스텔라테일러',
#  '코지마',
#  '바치',
#  '댄스킨',
#  '하동',
#  '무농약레드비트즙',
#  'TCOM_현대해상',
#  '상담접수상품뇌새김',
#  '뉴트리원',
#  '노와',
#  '메시제이',
#  '에펨',
#  '로벤탈',
#  '모즈',
#  '통오징어',
#  '시크릿뮤즈',
#  '삼성5도어냉장고',
#  '한세트',
#  '헤드',
#  '시크릿',
#  '경남제약',
#  '오렐리안',
#  '이롬',
#  '레드캠프',
#  '붙이는',
#  '참조기12팩',
#  '알비에로',
#  '히팅맘',
#  '궁중',
# ...

# %%
#com.to_csv('C:/Users/user/Downloads',index=False,encoding='utf-8')

# %%
#com_csv

# %%
라라쎄=performance[performance['상품명'].str.contains('라라쎄')]
라라쎄
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                상품명 상품군  \
# 15338  2019-05-24 14:00:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 15339  2019-05-24 14:20:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 15340  2019-05-24 14:40:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 15844  2019-05-29 10:00:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 15845  2019-05-29 10:20:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 15846  2019-05-29 10:40:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 17776  2019-06-16 08:00:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 17777  2019-06-16 08:20:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 17778  2019-06-16 08:40:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 18545  2019-06-24 09:00:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 18546  2019-06-24 09:20:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 18547  2019-06-24 09:40:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# ...

# %%
라라쎄_index=라라쎄.index
라라쎄_index
# Out:
# Int64Index([15338, 15339, 15340, 15844, 15845, 15846, 17776, 17777, 17778,
#             18545, 18546, 18547, 18906, 18907, 18908, 18987, 18988, 18989,
#             20970, 20971, 20972, 21448, 21449, 21450, 22416, 22417, 22418],
#            dtype='int64')

# %%
for i in 라라쎄_index:
    performance.loc[i,['브랜드']]='라라쎄'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-93ca24b7f1a0> in <module>
# ----> 1 for i in 라라쎄_index:
#       2     performance.loc[i,['브랜드']]='라라쎄'
#
# NameError: name '라라쎄_index' is not defined

# %%
performance[performance['브랜드']=='라라쎄']
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                상품명 상품군  \
# 15338  2019-05-24 14:00:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 15339  2019-05-24 14:20:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 15340  2019-05-24 14:40:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 15844  2019-05-29 10:00:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 15845  2019-05-29 10:20:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 15846  2019-05-29 10:40:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 17776  2019-06-16 08:00:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 17777  2019-06-16 08:20:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 17778  2019-06-16 08:40:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 18545  2019-06-24 09:00:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 18546  2019-06-24 09:20:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# 18547  2019-06-24 09:40:00    20  100479  201455  라라쎄 쉬폰 롤업재킷 2종 세트  의류
# ...

# %%
'''
for name in com_names:
    performance['브랜드']=performance.apply(temp_brand(performance,name))
    '''
# Out:
# "\nfor name in com_names:\n    performance['브랜드']=performance.apply(temp_brand(performance,name))\n    "

# %%
if '오슬로' in com_names:
    print(True)
# Out:
# True

# %%
if '노비타' in com_names:
    print(True)
# Out:
# True

# %%
if '센스하우스' in com_names:
    print(True)
# Out:
# True

# %%
#데이터프레임과 해당 브랜드를 입력하면, 상품명 중에 그 브랜드가 있는 경우, 그 인덱스를 return/ return_brand  호출
def temp_brand(df,name):
    List=[]
    name2=df[df['상품명'].str.contains(name)]
    indexs=name2.index
    List.append(indexs)
    return_brand(List,name)

# %%
# 해당 열, '브랜드'열을 그 브랜드 이름으로 채움
def return_brand(List,name):
    for i in List:
        performance.loc[i,['브랜드']]=name

# %%
if '(' in com_names:
    print(True)

# %%
for i in range(len(com_names)):
    #print(com_names[i])
    #print(name)
    temp_brand(performance,com_names[i])

# %%
temp_brand(performance,'테이트')

# %%
#return_brand(List,'라라쎄')

# %%
performance
# Out:
#                       방송일시    노출(분)    마더코드    상품코드                     상품명  \
# 1      2019-01-01 06:00:00       20  100346  201072           테이트 남성 셀린니트3종
# 2      2019-01-01 06:00:00      NaN  100346  201079           테이트 여성 셀린니트3종
# 3      2019-01-01 06:20:00       20  100346  201072           테이트 남성 셀린니트3종
# 4      2019-01-01 06:20:00      NaN  100346  201079           테이트 여성 셀린니트3종
# 5      2019-01-01 06:40:00       20  100346  201072           테이트 남성 셀린니트3종
# ...                    ...      ...     ...     ...                     ...
# 38305  2020-01-01 00:20:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험1912
# 38306  2020-01-01 00:40:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험1912
# 38307  2020-01-01 01:00:00       20  100073  200196  삼성화재 행복한파트너 주택화재보험1912
# 38308  2020-01-01 01:20:00       20  100490  201478        더케이 예다함 상조서비스티포트
# 38309  2020-01-01 01:40:00  17.1667  100490  201478        더케이 예다함 상조서비스티포트
#
#       상품군   판매단가      취급액  브랜드
# ...

# %%
#브랜드이름이 뉴로 잘못 선정/ 뉴 콜레린 임
performance[performance['브랜드']=='뉴 클레린']
# Out:
#                      방송일시 노출(분)    마더코드    상품코드                    상품명 상품군  \
# 2435  2019-01-27 06:00:00    20  100658  201986  뉴 클레린 티메이커 시그니처플러스 11  주방
# 2436  2019-01-27 06:00:00   NaN  100658  201987         뉴 클레린 티메이커 플러스  주방
# 2437  2019-01-27 06:20:00    20  100658  201986  뉴 클레린 티메이커 시그니처플러스 11  주방
# 2438  2019-01-27 06:20:00   NaN  100658  201987         뉴 클레린 티메이커 플러스  주방
# 2439  2019-01-27 06:40:00    20  100658  201986  뉴 클레린 티메이커 시그니처플러스 11  주방
# 2440  2019-01-27 06:40:00   NaN  100658  201987         뉴 클레린 티메이커 플러스  주방
# 3321  2019-02-05 15:00:00    20  100658  201986  뉴 클레린 티메이커 시그니처플러스 11  주방
# 3322  2019-02-05 15:00:00   NaN  100658  201987         뉴 클레린 티메이커 플러스  주방
# 3323  2019-02-05 15:20:00    20  100658  201986  뉴 클레린 티메이커 시그니처플러스 11  주방
# 3324  2019-02-05 15:20:00   NaN  100658  201987         뉴 클레린 티메이커 플러스  주방
# 3325  2019-02-05 15:40:00    20  100658  201986  뉴 클레린 티메이커 시그니처플러스 11  주방
# ...

# %%
performance[performance['브랜드']=='푸마']
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                    상품명 상품군  \
# 42     2019-01-01 19:00:00    20  100607  201892  푸마 에어핏 서포트 브라세트 15종4종  속옷
# 43     2019-01-01 19:20:00    20  100607  201892  푸마 에어핏 서포트 브라세트 15종4종  속옷
# 44     2019-01-01 19:40:00    20  100607  201892  푸마 에어핏 서포트 브라세트 15종4종  속옷
# 129    2019-01-02 20:00:00    20  100610  201901     푸마 코튼 라이크라 드로즈 12종  속옷
# 130    2019-01-02 20:00:00   NaN  100610  201862    푸마 INNO 심리스 롱드로즈 7종  속옷
# ...                    ...   ...     ...     ...                    ...  ..
# 38197  2019-12-30 23:40:00   NaN  100610  201884      푸마 시그니처 코튼 트렁크 9종  속옷
# 38198  2019-12-30 23:40:00   NaN  100610  201906           푸마 코튼 언더탑 9종  속옷
# 38199  2019-12-31 00:00:00    20  100610  201883    푸마 스트레치 심리스 드로즈 11종  속옷
# 38200  2019-12-31 00:00:00   NaN  100610  201884      푸마 시그니처 코튼 트렁크 9종  속옷
# 38201  2019-12-31 00:00:00   NaN  100610  201906           푸마 코튼 언더탑 9종  속옷
#
#          판매단가       취급액 브랜드
# ...

# %%
performance[performance['브랜드']=='시불']
# Out:
# Empty DataFrame
# Columns: [방송일시, 노출(분), 마더코드, 상품코드, 상품명, 상품군, 판매단가, 취급액, 브랜드]
# Index: []

# %%
performance[performance['브랜드']=='이자']
# Out:
# Empty DataFrame
# Columns: [방송일시, 노출(분), 마더코드, 상품코드, 상품명, 상품군, 판매단가, 취급액, 브랜드]
# Index: []

# %%
performance[performance['브랜드']=='햇']
# Out:
# Empty DataFrame
# Columns: [방송일시, 노출(분), 마더코드, 상품코드, 상품명, 상품군, 판매단가, 취급액, 브랜드]
# Index: []

# %%
performance[performance['브랜드']=='갑오징어']
# Out:
#                       방송일시 노출(분)    마더코드    상품코드          상품명  상품군   판매단가  \
# 33     2019-01-01 16:00:00    20  100322  201479      갑오징어 8팩  농수축  49900
# 34     2019-01-01 16:20:00    20  100322  201479      갑오징어 8팩  농수축  49900
# 488    2019-01-06 17:00:00    20  100322  201479      갑오징어 8팩  농수축  49900
# 489    2019-01-06 17:20:00    20  100322  201479      갑오징어 8팩  농수축  49900
# 490    2019-01-06 17:40:00    20  100322  201479      갑오징어 8팩  농수축  49900
# ...                    ...   ...     ...     ...          ...  ...    ...
# 37415  2019-12-22 12:20:00    20  100317  201004    햇 갑오징어 9팩  농수축  49900
# 37416  2019-12-22 12:40:00    20  100317  201004    햇 갑오징어 9팩  농수축  49900
# 38042  2019-12-28 22:20:00    20  100317  201004    햇 갑오징어 9팩  농수축  49900
# 38043  2019-12-28 22:40:00    20  100317  201004    햇 갑오징어 9팩  농수축  49900
# 38044  2019-12-28 23:00:00    20  100317  201004    햇 갑오징어 9팩  농수축  49900
#
#              취급액   브랜드
# 33      60787000  갑오징어
# 34     115457000  갑오징어
# ...

# %%
베스트하임=performance[performance['브랜드']=='베스트']
베스트하임
# Out:
#                       방송일시 노출(분)    마더코드    상품코드  \
# 1502   2019-01-17 09:00:00    20  100815  202419
# 1503   2019-01-17 09:20:00    20  100815  202419
# 1504   2019-01-17 09:40:00    20  100815  202419
# 1586   2019-01-18 08:00:00    20  100369  201161
# 1587   2019-01-18 08:20:00    20  100369  201161
# ...                    ...   ...     ...     ...
# 29704  2019-10-07 08:10:00    10  100095  200258
# 29705  2019-10-07 08:20:00    10  100095  200258
# 29706  2019-10-07 08:30:00    10  100095  200258
# 29707  2019-10-07 08:40:00    10  100095  200258
# 29708  2019-10-07 08:50:00    10  100095  200258
#
#                                        상품명 상품군   판매단가       취급액  브랜드
# 1502                         보코 퀼팅베스트터틀넥2종  의류  39000  16113000  베스트
# 1503                         보코 퀼팅베스트터틀넥2종  의류  39000  16447000  베스트
# 1504                         보코 퀼팅베스트터틀넥2종  의류  39000  27748000  베스트
# 1586                         메시제이 퀼팅코트퍼베스트  의류  79000   5290000  베스트
# ...

# %%
List1=[]
indexs=베스트하임.index
List1.append(indexs)
for i in List1:
    performance.loc[i,['브랜드']]='베스트하임'
performance[performance['브랜드']=='베스트하임']
# Out:
#                       방송일시 노출(분)    마더코드    상품코드  \
# 1502   2019-01-17 09:00:00    20  100815  202419
# 1503   2019-01-17 09:20:00    20  100815  202419
# 1504   2019-01-17 09:40:00    20  100815  202419
# 1586   2019-01-18 08:00:00    20  100369  201161
# 1587   2019-01-18 08:20:00    20  100369  201161
# ...                    ...   ...     ...     ...
# 29704  2019-10-07 08:10:00    10  100095  200258
# 29705  2019-10-07 08:20:00    10  100095  200258
# 29706  2019-10-07 08:30:00    10  100095  200258
# 29707  2019-10-07 08:40:00    10  100095  200258
# 29708  2019-10-07 08:50:00    10  100095  200258
#
#                                        상품명 상품군   판매단가       취급액    브랜드
# 1502                         보코 퀼팅베스트터틀넥2종  의류  39000  16113000  베스트하임
# 1503                         보코 퀼팅베스트터틀넥2종  의류  39000  16447000  베스트하임
# 1504                         보코 퀼팅베스트터틀넥2종  의류  39000  27748000  베스트하임
# 1586                         메시제이 퀼팅코트퍼베스트  의류  79000   5290000  베스트하임
# ...

# %%
스윙=performance[performance['브랜드']=='ALL']
스윙
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                     상품명  \
# 25705  2019-08-31 08:00:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 25706  2019-08-31 08:20:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 25707  2019-08-31 08:40:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27195  2019-09-14 18:20:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27196  2019-09-14 18:40:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27197  2019-09-14 19:00:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27556  2019-09-17 17:00:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27557  2019-09-17 17:20:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27558  2019-09-17 17:40:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 28848  2019-09-29 15:00:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 28849  2019-09-29 15:20:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 28850  2019-09-29 15:40:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# ...

# %%
List2=[]
indexs=스윙.index
List2.append(indexs)
for i in List2:
    performance.loc[i,['브랜드']]='스윙'
performance[performance['브랜드']=='스윙']
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                     상품명  \
# 25705  2019-08-31 08:00:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 25706  2019-08-31 08:20:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 25707  2019-08-31 08:40:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27195  2019-09-14 18:20:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27196  2019-09-14 18:40:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27197  2019-09-14 19:00:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27556  2019-09-17 17:00:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27557  2019-09-17 17:20:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 27558  2019-09-17 17:40:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 28848  2019-09-29 15:00:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 28849  2019-09-29 15:20:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# 28850  2019-09-29 15:40:00    20  100397  201280  ALL New 파워스윙 물걸레 진공청소기
# ...

# %%
TS=performance[performance['브랜드']=='TS']
TS
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                  상품명  상품군  \
# 11978  2019-04-26 06:00:00    20  100775  202265         NEW TS샴푸세트추가  이미용
# 11979  2019-04-26 06:00:00   NaN  100775  202264     NEW TS샴푸/트리트먼트추가  이미용
# 11980  2019-04-26 06:20:00    20  100775  202265         NEW TS샴푸세트추가  이미용
# 11981  2019-04-26 06:20:00   NaN  100775  202264     NEW TS샴푸/트리트먼트추가  이미용
# 11982  2019-04-26 06:40:00    20  100775  202265         NEW TS샴푸세트추가  이미용
# 11983  2019-04-26 06:40:00   NaN  100775  202264     NEW TS샴푸/트리트먼트추가  이미용
# 13110  2019-05-06 01:20:00    20  100775  202265         NEW TS샴푸세트추가  이미용
# 13111  2019-05-06 01:20:00   NaN  100775  202264     NEW TS샴푸/트리트먼트추가  이미용
# 13112  2019-05-06 01:40:00    13  100775  202265         NEW TS샴푸세트추가  이미용
# 13113  2019-05-06 01:40:00   NaN  100775  202264     NEW TS샴푸/트리트먼트추가  이미용
# 14152  2019-05-14 01:00:00    20  100775  202265         NEW TS샴푸세트추가  이미용
# ...

# %%
이화=performance[performance['브랜드']=='올뉴']
이화
# ...

# %%
List3=[]
indexs=생쥴랑.index
List3.append(indexs)
for i in List3:
    performance.loc[i,['브랜드']]='생줄랑'
performance[performance['브랜드']=='생줄랑']
# Out:
#                       방송일시 노출(분)    마더코드    상품코드  \
# 22020  2019-07-26 11:00:00    20  100032  200047
# 22021  2019-07-26 11:20:00    20  100032  200047
# 22022  2019-07-26 11:40:00    20  100032  200047
# 22576  2019-08-01 00:00:00    20  100032  200047
# 22577  2019-08-01 00:20:00    20  100032  200047
# ...                    ...   ...     ...     ...
# 31286  2019-10-22 12:40:00    20  100033  200052
# 31287  2019-10-22 12:40:00   NaN  100033  200051
# 31288  2019-10-22 12:40:00   NaN  100033  200053
# 32648  2019-11-05 13:20:00    30  100033  200050
# 32649  2019-11-05 13:50:00    30  100033  200050
#
#                                   상품명 상품군     판매단가       취급액  브랜드
# 22020         생줄랑 14K 글로리아 목걸이 컬렉션 8종  잡화    99000  15056000  생줄랑
# 22021         생줄랑 14K 글로리아 목걸이 컬렉션 8종  잡화    99000  45512000  생줄랑
# 22022         생줄랑 14K 글로리아 목걸이 컬렉션 8종  잡화    99000  59923000  생줄랑
# 22576         생줄랑 14K 글로리아 목걸이 컬렉션 8종  잡화    99000  13158000  생줄랑
# ...

# %%
temp8=performance

# %%
temp8.to_csv('file9.csv',encoding='utf-8-sig')

# %%
한삼인=performance[performance['브랜드']=='한삼인순홍삼진7박스']
한삼인
# Out:
#                      방송일시 노출(분)    마더코드    상품코드              상품명   상품군  \
# 1580  2019-01-18 07:00:00    20  100054  200138   한삼인순홍삼진7박스 백A1  건강기능
# 1581  2019-01-18 07:00:00   NaN  100054  200137   한삼인순홍삼진7박스 백A1  건강기능
# 1582  2019-01-18 07:20:00    20  100054  200138   한삼인순홍삼진7박스 백A1  건강기능
# 1583  2019-01-18 07:20:00   NaN  100054  200137   한삼인순홍삼진7박스 백A1  건강기능
# 1584  2019-01-18 07:40:00    20  100054  200138   한삼인순홍삼진7박스 백A1  건강기능
# 1585  2019-01-18 07:40:00   NaN  100054  200137   한삼인순홍삼진7박스 백A1  건강기능
# 2365  2019-01-26 07:00:00    20  100054  200138   한삼인순홍삼진7박스 백A1  건강기능
# 2366  2019-01-26 07:00:00   NaN  100054  200137   한삼인순홍삼진7박스 백A1  건강기능
# 2367  2019-01-26 07:20:00    20  100054  200138   한삼인순홍삼진7박스 백A1  건강기능
# 2368  2019-01-26 07:20:00   NaN  100054  200137   한삼인순홍삼진7박스 백A1  건강기능
# 2369  2019-01-26 07:40:00    20  100054  200138   한삼인순홍삼진7박스 백A1  건강기능
# 2370  2019-01-26 07:40:00   NaN  100054  200137   한삼인순홍삼진7박스 백A1  건강기능
# ...

# %%
더블유베일=performance[performance['상품명'].str.contains('더블유베일')]
더블유베일
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                     상품명 상품군  \
# 926    2019-01-11 11:00:00    30  100336  201048  더블유베일 풀스킨 폭스카라 머스크랫 코트  의류
# 927    2019-01-11 11:30:00    30  100336  201048  더블유베일 풀스킨 폭스카라 머스크랫 코트  의류
# 1183   2019-01-13 23:00:00    30  100336  201048  더블유베일 풀스킨 폭스카라 머스크랫 코트  의류
# 1184   2019-01-13 23:30:00    30  100336  201048  더블유베일 풀스킨 폭스카라 머스크랫 코트  의류
# 2362   2019-01-26 06:00:00    20  100335  201047       더블유베일 캐시라이크 니트 4종  의류
# 2363   2019-01-26 06:20:00    20  100335  201047       더블유베일 캐시라이크 니트 4종  의류
# 2364   2019-01-26 06:40:00    20  100335  201047       더블유베일 캐시라이크 니트 4종  의류
# 2618   2019-01-29 07:00:00    20  100335  201047       더블유베일 캐시라이크 니트 4종  의류
# 2619   2019-01-29 07:20:00    20  100335  201047       더블유베일 캐시라이크 니트 4종  의류
# 2620   2019-01-29 07:40:00    20  100335  201047       더블유베일 캐시라이크 니트 4종  의류
# 2898   2019-02-01 08:00:00    20  100335  201047       더블유베일 캐시라이크 니트 4종  의류
# ...

# %%
더블유베일[더블유베일['브랜드'].str.contains('한삼인순홍삼진7박스')]
# Out:
# Empty DataFrame
# Columns: [방송일시, 노출(분), 마더코드, 상품코드, 상품명, 상품군, 판매단가, 취급액, 브랜드]
# Index: []

# %%
performance[performance['브랜드']==""]
# Out:
# Empty DataFrame
# Columns: [방송일시, 노출(분), 마더코드, 상품코드, 상품명, 상품군, 판매단가, 취급액, 브랜드]
# Index: []

# %%
performance[performance['브랜드']=='IH 옛 가마솥 세트']
# Out:
#                       방송일시 노출(분)    마더코드    상품코드          상품명 상품군   판매단가  \
# 28406  2019-09-25 06:00:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 28407  2019-09-25 06:20:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 28408  2019-09-25 06:40:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 30047  2019-10-10 07:00:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 30048  2019-10-10 07:20:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 30049  2019-10-10 07:40:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 30230  2019-10-12 06:00:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 30231  2019-10-12 06:20:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 30232  2019-10-12 06:40:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 30746  2019-10-17 08:00:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 30747  2019-10-17 08:20:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# 30748  2019-10-17 08:40:00    20  100724  202115  IH 옛 가마솥 세트  주방  62000
# ...

# %%
#return_brand('테이트 남성 셀린니트3종',com_names)

# %%
메리츠=performance[performance['상품명'].str.contains('메리츠')]
메리츠
# Out:
#                      방송일시 노출(분)    마더코드    상품코드                상품명 상품군 판매단가  \
# 6671  2019-03-09 23:20:00    60  100484  201462  무메리츠 올바른 간편보험1810  무형    0
#
#       취급액   브랜드
# 6671  NaN  무메리츠

# %%
List3=[]
indexs=메리츠.index
List3.append(indexs)
for i in List3:
    performance.loc[i,['브랜드']]='메리츠'
performance[performance['브랜드']=='메리츠']
# Out:
#                      방송일시 노출(분)    마더코드    상품코드                상품명 상품군 판매단가  \
# 6671  2019-03-09 23:20:00    60  100484  201462  무메리츠 올바른 간편보험1810  무형    0
#
#       취급액  브랜드
# 6671  NaN  메리츠

# %%
하림=performance[performance['상품명'].str.contains('하림')]
하림
# Out:
#                       방송일시 노출(분)    마더코드    상품코드          상품명  상품군   판매단가  \
# 24294  2019-08-16 17:00:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 24295  2019-08-16 17:20:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 24296  2019-08-16 17:40:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 24751  2019-08-20 22:00:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 24752  2019-08-20 22:20:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# ...                    ...   ...     ...     ...          ...  ...    ...
# 36869  2019-12-16 17:40:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 36870  2019-12-16 18:00:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 37406  2019-12-22 10:20:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 37407  2019-12-22 10:40:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 37408  2019-12-22 11:00:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
#
#             취급액          브랜드
# 24294  48255000  하림뼈없는양념닭발세트
# ...

# %%
List3=[]
indexs=하림.index
List3.append(indexs)
for i in List3:
    performance.loc[i,['브랜드']]='하림'
performance[performance['브랜드']=='하림']
# Out:
#                       방송일시 노출(분)    마더코드    상품코드          상품명  상품군   판매단가  \
# 24294  2019-08-16 17:00:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 24295  2019-08-16 17:20:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 24296  2019-08-16 17:40:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 24751  2019-08-20 22:00:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 24752  2019-08-20 22:20:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# ...                    ...   ...     ...     ...          ...  ...    ...
# 36869  2019-12-16 17:40:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 36870  2019-12-16 18:00:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 37406  2019-12-22 10:20:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 37407  2019-12-22 10:40:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
# 37408  2019-12-22 11:00:00    20  100499  201501  하림뼈없는양념닭발세트  농수축  39900
#
#             취급액 브랜드
# 24294  48255000  하림
# 24295  71246000  하림
# ...

# %%
제주=performance[performance['상품명'].str.contains('제주')]
제주
# Out:
#                       방송일시 노출(분)    마더코드    상품코드                 상품명   상품군  \
# 267    2019-01-04 06:00:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 268    2019-01-04 06:20:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 269    2019-01-04 06:40:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 1197   2019-01-14 01:00:00    20  100744  202182     제주 한라봉2박스천혜향1박스   농수축
# 1198   2019-01-14 01:20:00    20  100744  202182     제주 한라봉2박스천혜향1박스   농수축
# ...                    ...   ...     ...     ...                 ...   ...
# 37247  2019-12-20 10:40:00    20  100812  202397           제주갈치참조기세트   농수축
# 37248  2019-12-20 11:00:00    20  100812  202397           제주갈치참조기세트   농수축
# 38248  2019-12-31 15:20:00    20  100812  202397           제주갈치참조기세트   농수축
# 38249  2019-12-31 15:40:00    20  100812  202397           제주갈치참조기세트   농수축
# 38250  2019-12-31 16:00:00    20  100812  202397           제주갈치참조기세트   농수축
#
#         판매단가       취급액 브랜드
# 267    74900  10439000  제주
# ...

# %%
제주농장=제주[제주['상품명'].str.contains('제주농장')]
제주농장
# Out:
#                      방송일시 노출(분)    마더코드    상품코드                 상품명   상품군  \
# 267   2019-01-04 06:00:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 268   2019-01-04 06:20:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 269   2019-01-04 06:40:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 1279  2019-01-15 06:00:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 1280  2019-01-15 06:20:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 1281  2019-01-15 06:40:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 2089  2019-01-23 06:00:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 2090  2019-01-23 06:20:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
# 2091  2019-01-23 06:40:00    20  100651  201972  제주농장 유기 양배추진액 120포  건강기능
#
# 4615   2019-02-18 06:40:00    20  100134  200365         까사마루행거 2단  생활용품
# 5592   2019-02-28 06:00:00    20  100134  200365         까사마루행거 2단  생활용품
# 5593   2019-02-28 06:20:00    20  100134  200365         까사마루행거 2단  생활용품
# 5594   2019-02-28 06:40:00    20  100134  200365         까사마루행거 2단  생활용품
# 6884   2019-03-12 06:00:00    20  100134  200365         까사마루행거 2단  생활용품
# 6885   2019-03-12 06:20:00    20  100134  200365         까사마루행거 2단  생활용품
# 6886   2019-03-12 06:40:00    20  100134  200365         까사마루행거 2단  생활용품
# 7614   2019-03-19 06:00:00    20  100134  200365         까사마루행거 2단  생활용품
# 7615   2019-03-19 06:20:00    20  100134  200365         까사마루행거 2단  생활용품
# 7616   2019-03-19 06:40:00    20  100134  200365         까사마루행거 2단  생활용품
# ...

# %%
'''
#상품명 중에 com_names 원소 있으면 'brand'열에 저장
#contains: i True:   그 인덱스 (행)에 ㅑ
for i in com_names:
    if performance['상품명'].str.contains(i)==True:
        performance['브랜드']=i
'''
# Out:
# "\n#상품명 중에 com_names 원소 있으면 'brand'열에 저장\n#contains: i True:   그 인덱스 (행)에 ㅑ\nfor i in com_names:\n    if performance['상품명'].str.contains(i)==True:\n        performance['브랜드']=i\n"

# %%
#추출한 브랜드/ 데이터 프레임상 일치하는 부분 있으면 새로운 열 만들어서 브랜드 따로 저장

# %%
# 브랜드별 데이터 프레임 만들고/ 상품코드 분류하기

# %%
# 브랜드별로 다 분류해서 상품코드 해보기

# %%
#상품명 대 상품코드
'''
tate_code=tate_cate.groupby(['상품명'])['상품코드'].mean()
tate_code=pd.DataFrame(tate_code)
tate_code
'''
# Out:
# "\ntate_code=tate_cate.groupby(['상품명'])['상품코드'].mean()\ntate_code=pd.DataFrame(tate_code)\ntate_code\n"

# %%
#광동/광동제약 : 광동제약으로 통일 필요
#생줄랑/생쥴랑 통일 필요
#베스트 하임/베스트하임

# %%
#쿠첸/쿠쿠 /린나이/매디쉴드 (이자/시불)문제
#한국인 모유유래 다이어트 유산균 BNR17 비에날씬 12주3박스 #에이스바이옴

# %%
#에이프릴/영산포숙성 홍어/카파/세인트스코트/제주바다/우리바다/11대신 옛날 그 쥐포/11대신에 뉴 클레린/바다먹자/바로바로/11대신에 벨라홈
#무 대신에 무 삼익가구/ 일 대신해 일 삼익가구/
#잃한샘/무한샘 대신에 일/무
#11대신에 김정문의
#일4인용 한샘/ 무
# LG 코드제로 무선청소기 A930 A938RA팩 대신에 무
#2019 S/S 엘리자베스아덴 선글라스 2종 대신에 2019
# 삼성 무풍슬림 스탠드  에어컨  AF16R5773WSK 대신에 무
# LG 코드제로 무선청소기 A940 A948SA 더블팩 대신에 무
#굿프렌드 굿터치클리너 11 대신에 11
#플로쥬 트윙클 아일렛 스니커즈 대신에 일
# 해피콜 크로커다일 IH후라이팬 대신에 IH
#IH는 브랜드 아님
#파뷔에 항균도마 11세트 대신에 11
# 삼성 5도어 냉장고 H9000 RH81M8011S9 대신에 11
#무보루네오 유로탑 가죽 침대  대신에 무

#F11035 까지 봄
